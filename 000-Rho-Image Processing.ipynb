# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Sources
#
# Ravi, J. (2019). Building Clustering Models with scikit-learn, video recording, Pluralsight. Available from https://app.pluralsight.com/library/courses/building-clustering-models-scikit-learn/table-of-contents

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Images should all be the same size. So a set of 10 color images that are 6x6 pixels will be represnted by (10,6,6,3).
# - 10 is the # images
# - a 6x6 image (length x width)
# - 3 is the number of channels: 1 for B&W, 3 for color

# %% [markdown]
# # MNIST handwritten digits dataset
#
# http://yann.lecun.com/exdb/mnist/
# - 42000 records
# - 785 features: 28*28
# - I think you can have better prediction on the numbers if you use more than 10 clusters
